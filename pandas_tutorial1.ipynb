# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# These options are probably for python2 version of pandas
#pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
#plt.rcParam['figure.figsize'] = (15, 5)

# %%
broken_df = pd.read_csv('data/bikes.csv')

# %%
# Look at the first 3 rows
broken_df[:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
fixed_df = pd.read_csv('data/bikes.csv', dayfirst=True, parse_dates=['Date'], index_col='Date')
fixed_df[:3]
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
#
#             Maisonneuve_1  Brébeuf  Parc  PierDup  \
# Date
# 2012-01-01             38      5.0    26       10
# 2012-01-02             68     11.0    53        6
# 2012-01-03            104      2.0    89        3
#
#             CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01                            0                  27.0
# 2012-01-02                            1                  21.0
# 2012-01-03                            2                  15.0

# %%
fixed_df['Berri1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-12-02     324
# 2012-12-03    1286
# 2012-12-04    1264
# 2012-12-05    1204
# 2012-12-06    1252
# 2012-12-07    1151
# 2012-12-08     382
# 2012-12-09     427
# 2012-12-10     245
# 2012-12-11     517
# 2012-12-12     598
# 2012-12-13     655
# 2012-12-14     738
# 2012-12-15     335
# 2012-12-16     177
# 2012-12-17     236
# ...

# %%
fixed_df['Berri1'].plot(figsize=(20, 10))

# %%
fixed_df.plot(figsize=(15, 10))

# %%
# %time sum([x for x in range(100000)])
# Out:
# CPU times: user 17.5 ms, sys: 4.66 ms, total: 22.2 ms
# Wall time: 19.7 ms
# 4999950000

# %%
# %time sum(x for x in range(100000))
# Out:
# CPU times: user 10.5 ms, sys: 890 µs, total: 11.3 ms
# Wall time: 10.9 ms
# 4999950000

# %%
# %quickref

# %%
# %%perl
# $_ = "whoa, python!";
# s/python/perl/;
# print
# Out:
# whoa, perl!

# %%
# %magic

# %%
# %who
# Out:
# broken_df	 fixed_df	 pd	 plt
