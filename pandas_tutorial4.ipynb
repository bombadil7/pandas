# %%
# %matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'

url_template =  "http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data"
url = url_template.format(month=3, year=2012)
#weather_mar2012 = pd.read_csv(url, skiprows=15, index_col='Date/Time', parse_dates=True, encoding='latin1', header=True)
weather_2012 = pd.read_csv('pandas-cookbook/data/weather_2012.csv', 
                          parse_dates=True)
mar_filter = list(map(lambda x: '2012-03' in x, weather_2012['Date/Time']))
weather_mar2012 = weather_2012[mar_filter]
weather_mar2012.set_index('Date/Time', inplace=True)
weather_mar2012[:3]
# %matplotlib inline
weather_mar2012["Temp (C)"].plot(figsize=(15,5))
temperatures = weather_mar2012[[u'Temp (C)']].copy()
#print(temperatures.head)
temperatures.loc[:'Hour'] = weather_mar2012.index.hour
#temperatures.groupby('Hour').aggregate(np.median).plot()
# Out:
# Using matplotlib backend: Qt5Agg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-161f8fd96fca> in <module>()
#      20 temperatures = weather_mar2012[[u'Temp (C)']].copy()
#      21 #print(temperatures.head)
# ---> 22 temperatures.loc[:'Hour'] = weather_mar2012.index.hour
#      23 #temperatures.groupby('Hour').aggregate(np.median).plot()
#
# AttributeError: 'Index' object has no attribute 'hour'

# %%
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-03-01 00:00:00      -5.5                -9.7           72
# 2012-03-01 01:00:00      -5.7                -8.7           79
# 2012-03-01 02:00:00      -5.4                -8.3           80
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-03-01 00:00:00               24              4.0           100.97    Snow
# 2012-03-01 01:00:00               26              2.4           100.87    Snow
# 2012-03-01 02:00:00               28              4.8           100.80    Snow

# %%
#test_range = pd.Series(pd.date_range("2012-01-08", "2012-04-12"))
#[date, time] = list(map(lambda x: x.split(' '), weather_mar2012.index))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-b74c00bbc861> in <module>()
#       1 #test_range = pd.Series(pd.date_range("2012-01-08", "2012-04-12"))
# ----> 2 [date, time] = list(map(lambda x: x.split(' '), weather_mar2012.index))
#
# ValueError: too many values to unpack (expected 2)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-e435778d5556> in <module>()
#       1 temperatures = weather_mar2012[[u'Temp (C)']].copy()
#       2 #print(temperatures.head)
# ----> 3 temperatures.loc[:'Hour'] = weather_mar2012.index.hour
#       4 #temperatures.groupby('Hour').aggregate(np.median).plot()
#
# AttributeError: 'Index' object has no attribute 'hour'

# %%
# Out:
# RangeIndex(start=0, stop=96, step=1)
